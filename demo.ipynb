# %%
from utils_rott import * # this is bad style, but there are a handful of functions in utils_rott, so live with it :)
import matplotlib.pylab as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Linear Regime

# %%
s0=RottSetup() # The default setup corresonds to a linear behavior 
pp0=RottProperties(s0)   
t0=RottTrajectoryInPhasespace(s0,pp0)
t0.integrate(int_scheme=0) # integrate the pendulums dynamic for 60s

# %%
f,ax=plt.subplots()
f,ax=t0.plot(f=f,ax=ax)
ax.set_xlim([0,20])
f.savefig("linear_plot.png")

# %%
t0.animate_rott("linear")
# Out:
# t:   0%|          | 5/1000 [00:00<00:21, 45.52it/s, now=None]
# MoviePy - Building file linear.gif with imageio.

# %% [markdown]
# ### Chaotic Regime

# %%
# Let's set the initial conditions for two pendula via the Setup
adot0_ = 500.
s1=RottSetup(g0=0.,gdot0=0.0,adot0=adot0_)
s2=RottSetup(g0=0.,gdot0=0.0,adot0=adot0_*1.001) # at t=0 the second pendulum left arm has a slightly higher angular velocity adot0

pp1=RottProperties(s1)    
pp2=RottProperties(s2)

# %%
t1=RottTrajectoryInPhasespace(s1,pp1)
t1.integrate(int_scheme=0) # integrate the pendulums dynamic for 60s

t2=RottTrajectoryInPhasespace(s2,pp2)
t2.integrate(int_scheme=0) # integrate the pendulums dynamic for 60s

# %% [markdown]
# Now let's inspect how the the two pendulas motion evolve with time:

# %%
f,ax=plt.subplots()
t1.plot(f=f,ax=ax)
t2.plot(f=f,ax=ax)

ax.set_xlim([0,5])
ax.set_xlabel("t in s")
ax.set_ylabel(r"$\alpha$ and $\gamma$ in rad / s")
fig.savefig("sensitivity.png")
# Out:
# Text(21.90625, 0.5, '$\\alpha$ and $\\gamma$ in rad / s')

# %%
f2,ax2=plt.subplots()
t1.plot(f=f,ax=ax2)
ax2.set_xlim([0,20])
f2.savefig("chaotic_plot.png")

# %% [markdown]
# Can you see how the respective angular speeds start to differ after 1.5 s? Reducing the difference in initial conditions will have a logarithmically small impact.

# %%
t1.animate_rott("chaotic")
# Out:
# t:   0%|          | 4/1000 [00:00<00:30, 32.94it/s, now=None]
# MoviePy - Building file chaotic.gif with imageio.

# %%
t2.animate_rott("chaotic_2")
# Out:
# t:   0%|          | 4/1000 [00:00<00:31, 31.55it/s, now=None]
# MoviePy - Building file chaotic_2.gif with imageio.
